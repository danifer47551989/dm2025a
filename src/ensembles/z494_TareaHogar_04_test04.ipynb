# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# Esta Tarea para el Hogar 02 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el viernes 01-agosto

# %% [markdown]
# ##  1. Cazatalentos

# %% [markdown]
# En la Clase 03 nos hemos enfrentado a  "La Maldicion del Ganandor",  elegir el modelo con el mejor puntaje simple no suele ser la mejor estrategia.
# <br> Lea y ejecute el notebook  **src/CazaTalentos/CazaTalentos.ipynb**
# <br> en caso de interesarle, participe del Desafío Ordenamiento  que vence el sábado 02 de agosto a las 19:00

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Error in parse(text = input): <text>:2:6: unexpected symbol
# 1: # primero establecer el Runtime de Python 3
# 2: from google.colab
#         ^
# Traceback:

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dm"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dm" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/itba2025-8d0a/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 15:46:07 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb)  gc trigger (Mb)   max used  (Mb)
# Ncells 2396651 128.0   7542764   402.9   7542764  402.9
# Vcells 4535067  34.6 168540480  1285.9 190210232 1451.2

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 49888
PARAM$semilla_primigenia <- 100019

# %%
PARAM$kaggle$competencia <- "data-mining-analista-sr-2025-a"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# =====================================
# Parámetros LightGBM (fijos)
# =====================================
PARAM$hyperparametertuning$xval_folds <- 5

PARAM$lgbm$param_fijos <- list(
  boosting = "gbdt",
  objective = "binary",
  metric = "auc",
  first_metric_only = TRUE,
  boost_from_average = TRUE,
  feature_pre_filter = FALSE,
  force_row_wise = TRUE,
  verbosity = -100,
  seed = PARAM$semilla_primigenia,
  num_iterations = 400,            # Aumentamos iteraciones
  early_stopping_round = 50        # Early stopping para evitar overfit
)

# =====================================
# Rango de hiperparámetros para Bayesiana
# =====================================
PARAM$lgbm$param_BO <- list(
  num_leaves               = c(10L, 80L),
  min_data_in_leaf         = c(1L, 50L),
  learning_rate            = c(0.01, 0.15),           # Rango más bajo, más iteraciones
  feature_fraction         = c(0.8, 1.0),
  bagging_fraction         = c(0.8, 1.0),
  max_depth                = c(3L, 8L),
  min_sum_hessian_in_leaf  = c(1e-3, 0.1),
  lambda_l1                = c(0, 5),
  lambda_l2                = c(0, 5),
  min_gain_to_split        = c(0, 0.1),
  min_data_in_bin          = c(1L, 10L),              # NUEVO
  max_bin                  = c(63L, 255L),            # NUEVO
  scale_pos_weight         = c(0.5, 5)                # NUEVO (si hay desbalance)
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# =====================================
# ParamSet para mlrMBO
# =====================================
PARAM$hyperparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 10L, upper = 80L),
  makeIntegerParam("min_data_in_leaf", lower = 1L, upper = 50L),
  makeNumericParam("learning_rate", lower = 0.01, upper = 0.15),
  makeNumericParam("feature_fraction", lower = 0.8, upper = 1.0),
  makeNumericParam("bagging_fraction", lower = 0.8, upper = 1.0),
  makeIntegerParam("max_depth", lower = 3L, upper = 8L),
  makeNumericParam("min_sum_hessian_in_leaf", lower = 1e-3, upper = 0.1),
  makeNumericParam("lambda_l1", lower = 0, upper = 5),
  makeNumericParam("lambda_l2", lower = 0, upper = 5),
  makeNumericParam("min_gain_to_split", lower = 0, upper = 0.1),
  makeIntegerParam("min_data_in_bin", lower = 1L, upper = 10L),   # NUEVO
  makeIntegerParam("max_bin", lower = 63L, upper = 255L),         # NUEVO
  makeNumericParam("scale_pos_weight", lower = 0.5, upper = 5)    # NUEVO
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 400 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83617
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set = PARAM$hyperparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Thu Jul 31 15:47:08 2025 AUC 0.92814999780262
#
# Thu Jul 31 15:47:17 2025 AUC 0.928254325942959
#
# Thu Jul 31 15:47:24 2025 AUC 0.926717695401019
#
# Thu Jul 31 15:47:44 2025 AUC 0.929012988385281
#
# Thu Jul 31 15:47:56 2025 AUC 0.928982778080411
#
# Thu Jul 31 15:48:05 2025 AUC 0.929062495225732
#
# Thu Jul 31 15:48:12 2025 AUC 0.926038730671154
#
# Thu Jul 31 15:48:22 2025 AUC 0.927748618057902
#
# Thu Jul 31 15:48:28 2025 AUC 0.925631545501041
#
# Thu Jul 31 15:48:53 2025 AUC 0.928106015351374
#
# Thu Jul 31 15:49:00 2025 AUC 0.925504556258362
#
# Thu Jul 31 15:49:06 2025 AUC 0.927914416674445
#
# Thu Jul 31 15:49:18 2025 AUC 0.928997588809676
#
# Thu Jul 31 15:49:25 2025 AUC 0.92711822743112
#
# Thu Jul 31 15:49:30 2025 AUC 0.922533507762961
#
# Thu Jul 31 15:49:46 2025 AUC 0.928526536667965
#
# Thu Jul 31 15:49:51 2025 AUC 0.926432805612676
#
# Thu Jul 31 15:50:06 2025 AUC 0.928728874376849
#
# Thu Jul 31 15:50:17 2025 AUC 0.929039241695948
#
# Thu Jul 31 15:50:26 2025 AUC 0.928763633938551
#
# Thu Jul 31 15:50:35 2025 AUC 0.929082954264218
#
# Thu Jul 31 15:50:52 2025 AUC 0.927449391553001
#
# Thu Jul 31 15:51:00 2025 AUC 0.92943951161791
#
# Thu Jul 31 15:51:11 2025 AUC 0.929546954762389
#
# Thu Jul 31 15:51:25 2025 AUC 0.928435606248024
#
# Thu Jul 31 15:51:34 2025 AUC 0.929252415366941
#
# Thu Jul 31 15:51:46 2025 AUC 0.92843355946166
#
# Thu Jul 31 15:51:52 2025 AUC 0.927175870969549
#
# Thu Jul 31 15:52:18 2025 AUC 0.92947121201798
#
# Thu Jul 31 15:52:28 2025 AUC 0.929935729291738
#
# Thu Jul 31 15:52:41 2025 AUC 0.923960351481952
#
# Thu Jul 31 15:52:52 2025 AUC 0.928120907780396
#
# Thu Jul 31 15:53:01 2025 AUC 0.929054274588234
#
# Thu Jul 31 15:53:12 2025 AUC 0.926865706896351
#
# Thu Jul 31 15:53:21 2025 AUC 0.927950412452757
#
# Thu Jul 31 15:53:29 2025 AUC 0.929446380057242
#
# Thu Jul 31 15:53:40 2025 AUC 0.924019728403246
#
# Thu Jul 31 15:53:50 2025 AUC 0.929075362520339
#
# Thu Jul 31 15:54:00 2025 AUC 0.928375062573643
#
# Thu Jul 31 15:54:08 2025 AUC 0.923390066601663
#
# Thu Jul 31 15:54:16 2025 AUC 0.930314810873541
#
# Thu Jul 31 15:54:40 2025 AUC 0.929048174416253
#
# Thu Jul 31 15:54:46 2025 AUC 0.926465942402585
#
# Thu Jul 31 15:54:57 2025 AUC 0.928972381700597
#
# Thu Jul 31 15:55:10 2025 AUC 0.928483166583643
#
# Thu Jul 31 15:55:16 2025 AUC 0.927187901111595
#
# Thu Jul 31 15:55:28 2025 AUC 0.928319220296921
#
# Thu Jul 31 15:55:50 2025 AUC 0.929549406622567
#
# Thu Jul 31 15:56:00 2025 AUC 0.929643814039987
#
# Thu Jul 31 15:56:09 2025 AUC 0.927351885058293
#
# Thu Jul 31 15:56:21 2025 AUC 0.927688007592999
#
# Thu Jul 31 15:56:27 2025 AUC 0.928378674724273
#
# [mbo] 0: num_leaves=48; min_data_in_leaf=6; learning_rate=0.0754; feature_fraction=0.815; bagging_fraction=0.867; max_depth=6; min_sum_hessian_in_leaf=0.0428; lambda_l1=2.84; lambda_l2=1.9; min_gain_to_split=0.053; min_data_in_bin=6; max_bin=203; scale_pos_weight=2.95 : y = 0.928 : 11.1 secs : initdesign
#
# [mbo] 0: num_leaves=53; min_data_in_leaf=10; learning_rate=0.086; feature_fraction=0.82; bagging_fraction=0.849; max_depth=5; min_sum_hessian_in_leaf=0.0585; lambda_l1=3.06; lambda_l2=2.7; min_gain_to_split=0.0547; min_data_in_bin=3; max_bin=161; scale_pos_weight=2.57 : y = 0.928 : 9.0 secs : initdesign
#
# [mbo] 0: num_leaves=57; min_data_in_leaf=18; learning_rate=0.12; feature_fraction=0.917; bagging_fraction=0.924; max_depth=6; min_sum_hessian_in_leaf=0.0636; lambda_l1=3.68; lambda_l2=4.21; min_gain_to_split=0.0381; min_data_in_bin=4; max_bin=217; scale_pos_weight=2.37 : y = 0.927 : 7.5 secs : initdesign
#
# [mbo] 0: num_leaves=38; min_data_in_leaf=28; learning_rate=0.0395; feature_fraction=0.851; bagging_fraction=0.852; max_depth=6; min_sum_hessian_in_leaf=0.061; lambda_l1=4.22; lambda_l2=1.55; min_gain_to_split=0.0655; min_data_in_bin=5; max_bin=182; scale_pos_weight=0.715 : y = 0.929 : 19.8 secs : initdesign
#
# [mbo] 0: num_leaves=63; min_data_in_leaf=33; learning_rate=0.0241; feature_fraction=0.993; bagging_fraction=0.918; max_depth=4; min_sum_hessian_in_leaf=0.0556; lambda_l1=2.16; lambda_l2=4.3; min_gain_to_split=0.0567; min_data_in_bin=8; max_bin=117; scale_pos_weight=3.23 : y = 0.929 : 11.5 secs : initdesign
#
# [mbo] 0: num_leaves=45; min_data_in_leaf=31; learning_rate=0.113; feature_fraction=0.945; bagging_fraction=0.863; max_depth=3; min_sum_hessian_in_leaf=0.0688; lambda_l1=3.09; lambda_l2=1.71; min_gain_to_split=0.0812; min_data_in_bin=6; max_bin=131; scale_pos_weight=1.38 : y = 0.929 : 9.6 secs : initdesign
#
# [mbo] 0: num_leaves=40; min_data_in_leaf=32; learning_rate=0.143; feature_fraction=0.834; bagging_fraction=0.889; max_depth=6; min_sum_hessian_in_leaf=0.0726; lambda_l1=3.31; lambda_l2=0.727; min_gain_to_split=0.029; min_data_in_bin=2; max_bin=168; scale_pos_weight=2.04 : y = 0.926 : 6.9 secs : initdesign
#
# [mbo] 0: num_leaves=23; min_data_in_leaf=22; learning_rate=0.0791; feature_fraction=0.941; bagging_fraction=0.963; max_depth=5; min_sum_hessian_in_leaf=0.0243; lambda_l1=1.95; lambda_l2=0.924; min_gain_to_split=0.0637; min_data_in_bin=6; max_bin=204; scale_pos_weight=4.46 : y = 0.928 : 9.6 secs : initdesign
#
# [mbo] 0: num_leaves=68; min_data_in_leaf=17; learning_rate=0.121; feature_fraction=0.873; bagging_fraction=0.922; max_depth=5; min_sum_hessian_in_leaf=0.0263; lambda_l1=1.88; lambda_l2=2.81; min_gain_to_split=0.0434; min_data_in_bin=3; max_bin=163; scale_pos_weight=3.57 : y = 0.926 : 6.6 secs : initdesign
#
# [mbo] 0: num_leaves=70; min_data_in_leaf=49; learning_rate=0.0129; feature_fraction=0.953; bagging_fraction=0.893; max_depth=7; min_sum_hessian_in_leaf=0.0889; lambda_l1=3.54; lambda_l2=2.48; min_gain_to_split=0.0273; min_data_in_bin=6; max_bin=124; scale_pos_weight=2.6 : y = 0.928 : 25.0 secs : initdesign
#
# [mbo] 0: num_leaves=41; min_data_in_leaf=20; learning_rate=0.106; feature_fraction=0.886; bagging_fraction=0.911; max_depth=7; min_sum_hessian_in_leaf=0.0767; lambda_l1=1.5; lambda_l2=2.25; min_gain_to_split=0.00867; min_data_in_bin=7; max_bin=99; scale_pos_weight=3.13 : y = 0.926 : 6.9 secs : initdesign
#
# [mbo] 0: num_leaves=52; min_data_in_leaf=23; learning_rate=0.103; feature_fraction=0.811; bagging_fraction=0.947; max_depth=5; min_sum_hessian_in_leaf=0.00335; lambda_l1=3.95; lambda_l2=1.33; min_gain_to_split=0.0224; min_data_in_bin=8; max_bin=90; scale_pos_weight=1.93 : y = 0.928 : 5.6 secs : initdesign
#
# [mbo] 0: num_leaves=66; min_data_in_leaf=35; learning_rate=0.0818; feature_fraction=0.865; bagging_fraction=0.828; max_depth=6; min_sum_hessian_in_leaf=0.0571; lambda_l1=1.76; lambda_l2=4.57; min_gain_to_split=0.0696; min_data_in_bin=2; max_bin=140; scale_pos_weight=1.32 : y = 0.929 : 12.1 secs : initdesign
#
# [mbo] 0: num_leaves=18; min_data_in_leaf=37; learning_rate=0.139; feature_fraction=0.838; bagging_fraction=0.887; max_depth=6; min_sum_hessian_in_leaf=0.0327; lambda_l1=2.95; lambda_l2=1.25; min_gain_to_split=0.0875; min_data_in_bin=10; max_bin=214; scale_pos_weight=2.74 : y = 0.927 : 6.7 secs : initdesign
#
# [mbo] 0: num_leaves=79; min_data_in_leaf=41; learning_rate=0.136; feature_fraction=0.866; bagging_fraction=0.913; max_depth=6; min_sum_hessian_in_leaf=0.0854; lambda_l1=1.02; lambda_l2=2.98; min_gain_to_split=0.0805; min_data_in_bin=4; max_bin=108; scale_pos_weight=4.24 : y = 0.923 : 5.1 secs : initdesign
#
# [mbo] 0: num_leaves=31; min_data_in_leaf=3; learning_rate=0.0404; feature_fraction=0.839; bagging_fraction=0.943; max_depth=6; min_sum_hessian_in_leaf=0.0653; lambda_l1=3.58; lambda_l2=0.995; min_gain_to_split=0.051; min_data_in_bin=7; max_bin=171; scale_pos_weight=1.69 : y = 0.929 : 16.1 secs : initdesign
#
# [mbo] 0: num_leaves=16; min_data_in_leaf=29; learning_rate=0.141; feature_fraction=0.912; bagging_fraction=0.981; max_depth=4; min_sum_hessian_in_leaf=0.0223; lambda_l1=1.37; lambda_l2=3.55; min_gain_to_split=0.0615; min_data_in_bin=9; max_bin=73; scale_pos_weight=3.44 : y = 0.926 : 5.5 secs : initdesign
#
# [mbo] 0: num_leaves=54; min_data_in_leaf=16; learning_rate=0.0428; feature_fraction=0.937; bagging_fraction=0.878; max_depth=8; min_sum_hessian_in_leaf=0.0126; lambda_l1=4.85; lambda_l2=1.06; min_gain_to_split=0.0396; min_data_in_bin=5; max_bin=150; scale_pos_weight=3.85 : y = 0.929 : 14.6 secs : initdesign
#
# [mbo] 0: num_leaves=32; min_data_in_leaf=14; learning_rate=0.0649; feature_fraction=0.857; bagging_fraction=0.841; max_depth=5; min_sum_hessian_in_leaf=0.0165; lambda_l1=4.54; lambda_l2=1.95; min_gain_to_split=0.0935; min_data_in_bin=1; max_bin=186; scale_pos_weight=4.74 : y = 0.929 : 11.3 secs : initdesign
#
# [mbo] 0: num_leaves=29; min_data_in_leaf=27; learning_rate=0.0883; feature_fraction=0.932; bagging_fraction=0.811; max_depth=4; min_sum_hessian_in_leaf=0.0532; lambda_l1=1.59; lambda_l2=3.25; min_gain_to_split=0.0265; min_data_in_bin=2; max_bin=119; scale_pos_weight=4.49 : y = 0.929 : 8.4 secs : initdesign
#
# [mbo] 0: num_leaves=19; min_data_in_leaf=9; learning_rate=0.116; feature_fraction=0.884; bagging_fraction=0.971; max_depth=8; min_sum_hessian_in_leaf=0.00691; lambda_l1=2.25; lambda_l2=3.31; min_gain_to_split=0.0161; min_data_in_bin=4; max_bin=179; scale_pos_weight=1.48 : y = 0.929 : 9.5 secs : initdesign
#
# [mbo] 0: num_leaves=16; min_data_in_leaf=21; learning_rate=0.0125; feature_fraction=0.923; bagging_fraction=0.821; max_depth=8; min_sum_hessian_in_leaf=0.0402; lambda_l1=0.0812; lambda_l2=3.66; min_gain_to_split=0.0973; min_data_in_bin=9; max_bin=154; scale_pos_weight=1.14 : y = 0.927 : 16.4 secs : initdesign
#
# [mbo] 0: num_leaves=45; min_data_in_leaf=25; learning_rate=0.0709; feature_fraction=0.825; bagging_fraction=0.932; max_depth=3; min_sum_hessian_in_leaf=0.0955; lambda_l1=0.415; lambda_l2=0.478; min_gain_to_split=0.0185; min_data_in_bin=1; max_bin=140; scale_pos_weight=2.13 : y = 0.929 : 8.9 secs : initdesign
#
# [mbo] 0: num_leaves=22; min_data_in_leaf=19; learning_rate=0.0913; feature_fraction=0.947; bagging_fraction=0.928; max_depth=3; min_sum_hessian_in_leaf=0.0825; lambda_l1=4.64; lambda_l2=4.71; min_gain_to_split=0.0904; min_data_in_bin=6; max_bin=194; scale_pos_weight=3.77 : y = 0.93 : 10.1 secs : initdesign
#
# [mbo] 0: num_leaves=24; min_data_in_leaf=45; learning_rate=0.0172; feature_fraction=0.972; bagging_fraction=0.884; max_depth=5; min_sum_hessian_in_leaf=0.0121; lambda_l1=3.92; lambda_l2=4.1; min_gain_to_split=0.0741; min_data_in_bin=5; max_bin=146; scale_pos_weight=3.08 : y = 0.928 : 14.8 secs : initdesign
#
# [mbo] 0: num_leaves=39; min_data_in_leaf=48; learning_rate=0.0853; feature_fraction=0.849; bagging_fraction=0.994; max_depth=5; min_sum_hessian_in_leaf=0.0665; lambda_l1=2.75; lambda_l2=3.81; min_gain_to_split=0.084; min_data_in_bin=3; max_bin=159; scale_pos_weight=2.48 : y = 0.929 : 8.8 secs : initdesign
#
# [mbo] 0: num_leaves=60; min_data_in_leaf=12; learning_rate=0.0959; feature_fraction=0.877; bagging_fraction=0.854; max_depth=7; min_sum_hessian_in_leaf=0.0282; lambda_l1=4.33; lambda_l2=4.34; min_gain_to_split=0.0581; min_data_in_bin=7; max_bin=248; scale_pos_weight=0.961 : y = 0.928 : 11.5 secs : initdesign
#
# [mbo] 0: num_leaves=37; min_data_in_leaf=35; learning_rate=0.0995; feature_fraction=0.909; bagging_fraction=0.813; max_depth=5; min_sum_hessian_in_leaf=0.0922; lambda_l1=4.09; lambda_l2=4.9; min_gain_to_split=0.00242; min_data_in_bin=9; max_bin=77; scale_pos_weight=3.91 : y = 0.927 : 6.4 secs : initdesign
#
# [mbo] 0: num_leaves=77; min_data_in_leaf=42; learning_rate=0.0303; feature_fraction=0.905; bagging_fraction=0.969; max_depth=8; min_sum_hessian_in_leaf=0.0182; lambda_l1=0.699; lambda_l2=3.58; min_gain_to_split=0.00636; min_data_in_bin=2; max_bin=234; scale_pos_weight=2.16 : y = 0.929 : 25.4 secs : initdesign
#
# [mbo] 0: num_leaves=13; min_data_in_leaf=4; learning_rate=0.0348; feature_fraction=0.922; bagging_fraction=0.961; max_depth=7; min_sum_hessian_in_leaf=0.0882; lambda_l1=3.22; lambda_l2=3.13; min_gain_to_split=0.0495; min_data_in_bin=10; max_bin=112; scale_pos_weight=4.73 : y = 0.93 : 10.8 secs : initdesign
#
# [mbo] 0: num_leaves=61; min_data_in_leaf=43; learning_rate=0.146; feature_fraction=0.963; bagging_fraction=0.861; max_depth=8; min_sum_hessian_in_leaf=0.00874; lambda_l1=2.07; lambda_l2=2.16; min_gain_to_split=0.0244; min_data_in_bin=7; max_bin=174; scale_pos_weight=2.81 : y = 0.924 : 12.8 secs : initdesign
#
# [mbo] 0: num_leaves=34; min_data_in_leaf=10; learning_rate=0.0513; feature_fraction=0.819; bagging_fraction=0.833; max_depth=8; min_sum_hessian_in_leaf=0.0442; lambda_l1=2.64; lambda_l2=3.87; min_gain_to_split=0.0342; min_data_in_bin=2; max_bin=126; scale_pos_weight=4.16 : y = 0.928 : 11.2 secs : initdesign
#
# [mbo] 0: num_leaves=34; min_data_in_leaf=8; learning_rate=0.0488; feature_fraction=0.997; bagging_fraction=0.902; max_depth=3; min_sum_hessian_in_leaf=0.0746; lambda_l1=1.24; lambda_l2=2.32; min_gain_to_split=0.0103; min_data_in_bin=4; max_bin=67; scale_pos_weight=0.647 : y = 0.929 : 9.0 secs : initdesign
#
# [mbo] 0: num_leaves=26; min_data_in_leaf=5; learning_rate=0.0266; feature_fraction=0.954; bagging_fraction=0.819; max_depth=3; min_sum_hessian_in_leaf=0.0214; lambda_l1=2.31; lambda_l2=0.539; min_gain_to_split=0.0415; min_data_in_bin=3; max_bin=231; scale_pos_weight=2.86 : y = 0.927 : 10.7 secs : initdesign
#
# [mbo] 0: num_leaves=75; min_data_in_leaf=30; learning_rate=0.0732; feature_fraction=0.928; bagging_fraction=0.978; max_depth=7; min_sum_hessian_in_leaf=0.0484; lambda_l1=0.853; lambda_l2=1.49; min_gain_to_split=0.0628; min_data_in_bin=10; max_bin=82; scale_pos_weight=0.849 : y = 0.928 : 9.2 secs : initdesign
#
# [mbo] 0: num_leaves=62; min_data_in_leaf=26; learning_rate=0.125; feature_fraction=0.903; bagging_fraction=0.991; max_depth=3; min_sum_hessian_in_leaf=0.0784; lambda_l1=1.66; lambda_l2=0.858; min_gain_to_split=0.00446; min_data_in_bin=10; max_bin=224; scale_pos_weight=1.76 : y = 0.929 : 8.0 secs : initdesign
#
# [mbo] 0: num_leaves=55; min_data_in_leaf=1; learning_rate=0.128; feature_fraction=0.961; bagging_fraction=0.935; max_depth=7; min_sum_hessian_in_leaf=0.0698; lambda_l1=3.38; lambda_l2=0.196; min_gain_to_split=0.0684; min_data_in_bin=3; max_bin=209; scale_pos_weight=2.24 : y = 0.924 : 10.2 secs : initdesign
#
# [mbo] 0: num_leaves=48; min_data_in_leaf=44; learning_rate=0.0624; feature_fraction=0.992; bagging_fraction=0.975; max_depth=3; min_sum_hessian_in_leaf=0.00175; lambda_l1=1.26; lambda_l2=0.377; min_gain_to_split=0.031; min_data_in_bin=2; max_bin=254; scale_pos_weight=1.07 : y = 0.929 : 10.8 secs : initdesign
#
# [mbo] 0: num_leaves=73; min_data_in_leaf=15; learning_rate=0.0469; feature_fraction=0.805; bagging_fraction=0.9; max_depth=3; min_sum_hessian_in_leaf=0.00628; lambda_l1=2.53; lambda_l2=2.52; min_gain_to_split=0.0984; min_data_in_bin=9; max_bin=197; scale_pos_weight=3.47 : y = 0.928 : 10.0 secs : initdesign
#
# [mbo] 0: num_leaves=64; min_data_in_leaf=7; learning_rate=0.112; feature_fraction=0.859; bagging_fraction=0.825; max_depth=8; min_sum_hessian_in_leaf=0.045; lambda_l1=2.42; lambda_l2=0.113; min_gain_to_split=0.000865; min_data_in_bin=9; max_bin=135; scale_pos_weight=4.93 : y = 0.923 : 7.4 secs : initdesign
#
# [mbo] 0: num_leaves=11; min_data_in_leaf=37; learning_rate=0.107; feature_fraction=0.966; bagging_fraction=1; max_depth=6; min_sum_hessian_in_leaf=0.0372; lambda_l1=3.84; lambda_l2=1.43; min_gain_to_split=0.0452; min_data_in_bin=5; max_bin=86; scale_pos_weight=0.81 : y = 0.93 : 8.7 secs : initdesign
#
# [mbo] 0: num_leaves=26; min_data_in_leaf=46; learning_rate=0.0204; feature_fraction=0.897; bagging_fraction=0.955; max_depth=8; min_sum_hessian_in_leaf=0.0378; lambda_l1=1.13; lambda_l2=0.091; min_gain_to_split=0.0944; min_data_in_bin=8; max_bin=252; scale_pos_weight=4 : y = 0.929 : 23.4 secs : initdesign
#
# [mbo] 0: num_leaves=14; min_data_in_leaf=42; learning_rate=0.126; feature_fraction=0.987; bagging_fraction=0.953; max_depth=4; min_sum_hessian_in_leaf=0.0297; lambda_l1=0.269; lambda_l2=4.93; min_gain_to_split=0.0134; min_data_in_bin=1; max_bin=227; scale_pos_weight=4.6 : y = 0.926 : 6.2 secs : initdesign
#
# [mbo] 0: num_leaves=28; min_data_in_leaf=50; learning_rate=0.0333; feature_fraction=0.829; bagging_fraction=0.845; max_depth=4; min_sum_hessian_in_leaf=0.0978; lambda_l1=0.115; lambda_l2=2.89; min_gain_to_split=0.0475; min_data_in_bin=8; max_bin=106; scale_pos_weight=1.25 : y = 0.929 : 10.7 secs : initdesign
#
# [mbo] 0: num_leaves=43; min_data_in_leaf=39; learning_rate=0.056; feature_fraction=0.892; bagging_fraction=0.906; max_depth=4; min_sum_hessian_in_leaf=0.0993; lambda_l1=4.76; lambda_l2=1.82; min_gain_to_split=0.0148; min_data_in_bin=1; max_bin=220; scale_pos_weight=3.35 : y = 0.928 : 13.3 secs : initdesign
#
# [mbo] 0: num_leaves=68; min_data_in_leaf=39; learning_rate=0.149; feature_fraction=0.802; bagging_fraction=0.837; max_depth=3; min_sum_hessian_in_leaf=0.0805; lambda_l1=4.29; lambda_l2=3.46; min_gain_to_split=0.0865; min_data_in_bin=7; max_bin=95; scale_pos_weight=3.68 : y = 0.927 : 6.1 secs : initdesign
#
# [mbo] 0: num_leaves=72; min_data_in_leaf=24; learning_rate=0.0681; feature_fraction=0.984; bagging_fraction=0.803; max_depth=4; min_sum_hessian_in_leaf=0.0936; lambda_l1=0.3; lambda_l2=4.45; min_gain_to_split=0.0912; min_data_in_bin=5; max_bin=244; scale_pos_weight=1.88 : y = 0.928 : 12.4 secs : initdesign
#
# [mbo] 0: num_leaves=80; min_data_in_leaf=34; learning_rate=0.021; feature_fraction=0.892; bagging_fraction=0.876; max_depth=8; min_sum_hessian_in_leaf=0.0522; lambda_l1=0.501; lambda_l2=4.69; min_gain_to_split=0.0199; min_data_in_bin=10; max_bin=102; scale_pos_weight=4.33 : y = 0.93 : 21.1 secs : initdesign
#
# [mbo] 0: num_leaves=58; min_data_in_leaf=16; learning_rate=0.0553; feature_fraction=0.974; bagging_fraction=0.804; max_depth=5; min_sum_hessian_in_leaf=0.015; lambda_l1=4.46; lambda_l2=2.04; min_gain_to_split=0.0785; min_data_in_bin=4; max_bin=81; scale_pos_weight=0.576 : y = 0.93 : 10.7 secs : initdesign
#
# [mbo] 0: num_leaves=49; min_data_in_leaf=11; learning_rate=0.059; feature_fraction=0.875; bagging_fraction=0.942; max_depth=7; min_sum_hessian_in_leaf=0.0842; lambda_l1=0.668; lambda_l2=0.598; min_gain_to_split=0.0767; min_data_in_bin=1; max_bin=64; scale_pos_weight=4.85 : y = 0.927 : 8.9 secs : initdesign
#
# [mbo] 0: num_leaves=76; min_data_in_leaf=47; learning_rate=0.098; feature_fraction=0.98; bagging_fraction=0.987; max_depth=7; min_sum_hessian_in_leaf=0.0492; lambda_l1=4.95; lambda_l2=4.03; min_gain_to_split=0.0722; min_data_in_bin=7; max_bin=238; scale_pos_weight=4.05 : y = 0.928 : 11.5 secs : initdesign
#
# [mbo] 0: num_leaves=10; min_data_in_leaf=2; learning_rate=0.133; feature_fraction=0.844; bagging_fraction=0.872; max_depth=4; min_sum_hessian_in_leaf=0.0352; lambda_l1=0.888; lambda_l2=2.61; min_gain_to_split=0.0359; min_data_in_bin=9; max_bin=192; scale_pos_weight=1.59 : y = 0.928 : 5.9 secs : initdesign
#
# Thu Jul 31 15:56:41 2025 AUC 0.929591407535744
#
# [mbo] 1: num_leaves=10; min_data_in_leaf=40; learning_rate=0.0909; feature_fraction=0.907; bagging_fraction=0.961; max_depth=6; min_sum_hessian_in_leaf=0.0204; lambda_l1=3.92; lambda_l2=4.18; min_gain_to_split=0.0368; min_data_in_bin=3; max_bin=180; scale_pos_weight=0.505 : y = 0.93 : 12.5 secs : infill_ei
#
# Thu Jul 31 15:56:52 2025 AUC 0.930057873862801
#
# [mbo] 2: num_leaves=16; min_data_in_leaf=42; learning_rate=0.107; feature_fraction=0.889; bagging_fraction=0.998; max_depth=3; min_sum_hessian_in_leaf=0.0311; lambda_l1=3.81; lambda_l2=3.07; min_gain_to_split=0.049; min_data_in_bin=6; max_bin=155; scale_pos_weight=0.778 : y = 0.93 : 9.8 secs : infill_ei
#
# Thu Jul 31 15:57:05 2025 AUC 0.930313653014236
#
# [mbo] 3: num_leaves=16; min_data_in_leaf=33; learning_rate=0.0845; feature_fraction=0.952; bagging_fraction=0.957; max_depth=4; min_sum_hessian_in_leaf=0.0443; lambda_l1=3.24; lambda_l2=3.91; min_gain_to_split=0.0583; min_data_in_bin=3; max_bin=119; scale_pos_weight=0.856 : y = 0.93 : 11.5 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Thu Jul 31 15:57:20 2025 AUC 0.92868575814823
#
# [mbo] 4: num_leaves=36; min_data_in_leaf=43; learning_rate=0.0913; feature_fraction=0.945; bagging_fraction=0.999; max_depth=3; min_sum_hessian_in_leaf=0.0841; lambda_l1=2.28; lambda_l2=2.42; min_gain_to_split=0.0187; min_data_in_bin=2; max_bin=120; scale_pos_weight=0.861 : y = 0.929 : 9.5 secs : infill_ei
#
# Thu Jul 31 15:57:33 2025 AUC 0.928654525632205
#
# [mbo] 5: num_leaves=12; min_data_in_leaf=33; learning_rate=0.0712; feature_fraction=0.923; bagging_fraction=0.865; max_depth=4; min_sum_hessian_in_leaf=0.0336; lambda_l1=2.77; lambda_l2=3.94; min_gain_to_split=0.0758; min_data_in_bin=4; max_bin=115; scale_pos_weight=1.32 : y = 0.929 : 11.0 secs : infill_ei
#
# Thu Jul 31 15:57:44 2025 AUC 0.929262211296796
#
# [mbo] 6: num_leaves=18; min_data_in_leaf=25; learning_rate=0.104; feature_fraction=0.852; bagging_fraction=0.983; max_depth=4; min_sum_hessian_in_leaf=0.0572; lambda_l1=3.94; lambda_l2=3.8; min_gain_to_split=0.0815; min_data_in_bin=5; max_bin=152; scale_pos_weight=0.634 : y = 0.929 : 9.8 secs : infill_ei
#
# Thu Jul 31 15:57:56 2025 AUC 0.929690099627336
#
# [mbo] 7: num_leaves=10; min_data_in_leaf=34; learning_rate=0.114; feature_fraction=0.994; bagging_fraction=0.987; max_depth=4; min_sum_hessian_in_leaf=0.0089; lambda_l1=4.68; lambda_l2=2.39; min_gain_to_split=0.0283; min_data_in_bin=8; max_bin=192; scale_pos_weight=0.929 : y = 0.93 : 10.0 secs : infill_ei
#
# Thu Jul 31 15:58:08 2025 AUC 0.929473621403732
#
# [mbo] 8: num_leaves=14; min_data_in_leaf=21; learning_rate=0.0868; feature_fraction=0.996; bagging_fraction=0.994; max_depth=5; min_sum_hessian_in_leaf=0.00381; lambda_l1=3.88; lambda_l2=4.66; min_gain_to_split=0.0671; min_data_in_bin=2; max_bin=104; scale_pos_weight=0.915 : y = 0.929 : 10.1 secs : infill_ei
#
# Thu Jul 31 15:58:25 2025 AUC 0.928944439282253
#
# [mbo] 9: num_leaves=62; min_data_in_leaf=39; learning_rate=0.0314; feature_fraction=0.892; bagging_fraction=0.989; max_depth=7; min_sum_hessian_in_leaf=0.0561; lambda_l1=2.12; lambda_l2=3.65; min_gain_to_split=0.0456; min_data_in_bin=10; max_bin=159; scale_pos_weight=4.72 : y = 0.929 : 16.1 secs : infill_ei
#
# Thu Jul 31 15:58:37 2025 AUC 0.928979207289701
#
# [mbo] 10: num_leaves=15; min_data_in_leaf=42; learning_rate=0.0867; feature_fraction=0.876; bagging_fraction=0.972; max_depth=3; min_sum_hessian_in_leaf=0.0408; lambda_l1=4.81; lambda_l2=1.52; min_gain_to_split=0.048; min_data_in_bin=7; max_bin=111; scale_pos_weight=1.19 : y = 0.929 : 9.4 secs : infill_ei
#
# Thu Jul 31 15:58:46 2025 AUC 0.929603267442424
#
# [mbo] 11: num_leaves=14; min_data_in_leaf=46; learning_rate=0.116; feature_fraction=0.883; bagging_fraction=0.979; max_depth=4; min_sum_hessian_in_leaf=0.0277; lambda_l1=0.54; lambda_l2=0.942; min_gain_to_split=0.0356; min_data_in_bin=9; max_bin=112; scale_pos_weight=0.565 : y = 0.93 : 7.5 secs : infill_ei
#
# Thu Jul 31 15:58:57 2025 AUC 0.928964304436972
#
# [mbo] 12: num_leaves=10; min_data_in_leaf=40; learning_rate=0.109; feature_fraction=0.948; bagging_fraction=0.948; max_depth=6; min_sum_hessian_in_leaf=0.0366; lambda_l1=3.11; lambda_l2=4.28; min_gain_to_split=0.049; min_data_in_bin=4; max_bin=185; scale_pos_weight=0.87 : y = 0.929 : 8.8 secs : infill_ei
#
# Thu Jul 31 15:59:07 2025 AUC 0.92890617110731
#
# [mbo] 13: num_leaves=11; min_data_in_leaf=34; learning_rate=0.11; feature_fraction=0.9; bagging_fraction=0.992; max_depth=4; min_sum_hessian_in_leaf=0.0231; lambda_l1=4.17; lambda_l2=0.483; min_gain_to_split=0.0472; min_data_in_bin=4; max_bin=73; scale_pos_weight=0.572 : y = 0.929 : 8.6 secs : infill_ei
#
# Thu Jul 31 15:59:20 2025 AUC 0.929876455382213
#
# [mbo] 14: num_leaves=22; min_data_in_leaf=33; learning_rate=0.085; feature_fraction=0.97; bagging_fraction=0.946; max_depth=4; min_sum_hessian_in_leaf=0.00742; lambda_l1=1.06; lambda_l2=3.42; min_gain_to_split=0.0478; min_data_in_bin=5; max_bin=180; scale_pos_weight=0.57 : y = 0.93 : 11.6 secs : infill_ei
#
# Thu Jul 31 15:59:32 2025 AUC 0.929695329736894
#
# [mbo] 15: num_leaves=38; min_data_in_leaf=37; learning_rate=0.081; feature_fraction=0.961; bagging_fraction=0.947; max_depth=5; min_sum_hessian_in_leaf=0.0225; lambda_l1=4.51; lambda_l2=3.77; min_gain_to_split=0.0411; min_data_in_bin=3; max_bin=135; scale_pos_weight=0.766 : y = 0.93 : 10.1 secs : infill_ei
#
# Thu Jul 31 15:59:46 2025 AUC 0.92998796108061
#
# [mbo] 16: num_leaves=19; min_data_in_leaf=24; learning_rate=0.0863; feature_fraction=0.955; bagging_fraction=0.975; max_depth=3; min_sum_hessian_in_leaf=0.0379; lambda_l1=3.77; lambda_l2=3.92; min_gain_to_split=0.0503; min_data_in_bin=2; max_bin=224; scale_pos_weight=1.41 : y = 0.93 : 11.5 secs : infill_ei
#
# Thu Jul 31 15:59:57 2025 AUC 0.928608169336828
#
# [mbo] 17: num_leaves=24; min_data_in_leaf=29; learning_rate=0.116; feature_fraction=0.94; bagging_fraction=0.996; max_depth=3; min_sum_hessian_in_leaf=0.0465; lambda_l1=2.1; lambda_l2=1.68; min_gain_to_split=0.0434; min_data_in_bin=10; max_bin=216; scale_pos_weight=0.676 : y = 0.929 : 9.2 secs : infill_ei
#
# Thu Jul 31 16:00:09 2025 AUC 0.928918195157326
#
# [mbo] 18: num_leaves=10; min_data_in_leaf=46; learning_rate=0.0928; feature_fraction=0.923; bagging_fraction=0.949; max_depth=3; min_sum_hessian_in_leaf=0.0304; lambda_l1=4.28; lambda_l2=4.12; min_gain_to_split=0.0621; min_data_in_bin=5; max_bin=141; scale_pos_weight=0.966 : y = 0.929 : 9.7 secs : infill_ei
#
# Thu Jul 31 16:00:21 2025 AUC 0.929616671720857
#
# [mbo] 19: num_leaves=10; min_data_in_leaf=30; learning_rate=0.0818; feature_fraction=0.866; bagging_fraction=0.958; max_depth=4; min_sum_hessian_in_leaf=0.0753; lambda_l1=3.47; lambda_l2=1.21; min_gain_to_split=0.0558; min_data_in_bin=1; max_bin=175; scale_pos_weight=0.787 : y = 0.93 : 10.2 secs : infill_ei
#
# Thu Jul 31 16:00:31 2025 AUC 0.92817111595129
#
# [mbo] 20: num_leaves=28; min_data_in_leaf=47; learning_rate=0.116; feature_fraction=0.877; bagging_fraction=1; max_depth=3; min_sum_hessian_in_leaf=0.0281; lambda_l1=3.67; lambda_l2=3.49; min_gain_to_split=0.00117; min_data_in_bin=8; max_bin=163; scale_pos_weight=1.56 : y = 0.928 : 8.4 secs : infill_ei
#
# Thu Jul 31 16:00:44 2025 AUC 0.929051715015341
#
# [mbo] 21: num_leaves=11; min_data_in_leaf=19; learning_rate=0.0859; feature_fraction=0.975; bagging_fraction=0.991; max_depth=5; min_sum_hessian_in_leaf=0.0433; lambda_l1=3.89; lambda_l2=3.08; min_gain_to_split=0.0494; min_data_in_bin=1; max_bin=137; scale_pos_weight=0.756 : y = 0.929 : 11.0 secs : infill_ei
#
# Thu Jul 31 16:01:02 2025 AUC 0.92882769160529
#
# [mbo] 22: num_leaves=44; min_data_in_leaf=17; learning_rate=0.0298; feature_fraction=0.95; bagging_fraction=0.82; max_depth=7; min_sum_hessian_in_leaf=0.0931; lambda_l1=3.23; lambda_l2=2.11; min_gain_to_split=0.0541; min_data_in_bin=10; max_bin=87; scale_pos_weight=4.13 : y = 0.929 : 16.1 secs : infill_ei
#
# Thu Jul 31 16:01:12 2025 AUC 0.929070151653328
#
# [mbo] 23: num_leaves=41; min_data_in_leaf=32; learning_rate=0.0815; feature_fraction=0.947; bagging_fraction=0.928; max_depth=3; min_sum_hessian_in_leaf=0.0356; lambda_l1=1.3; lambda_l2=2.34; min_gain_to_split=0.0789; min_data_in_bin=2; max_bin=194; scale_pos_weight=1.25 : y = 0.929 : 8.1 secs : infill_ei
#
# Thu Jul 31 16:01:23 2025 AUC 0.930033315172396
#
# [mbo] 24: num_leaves=10; min_data_in_leaf=41; learning_rate=0.106; feature_fraction=0.944; bagging_fraction=0.902; max_depth=5; min_sum_hessian_in_leaf=0.00338; lambda_l1=2.42; lambda_l2=1.7; min_gain_to_split=0.059; min_data_in_bin=6; max_bin=145; scale_pos_weight=0.528 : y = 0.93 : 9.0 secs : infill_ei
#
# Thu Jul 31 16:01:35 2025 AUC 0.928294468261306
#
# [mbo] 25: num_leaves=23; min_data_in_leaf=32; learning_rate=0.0849; feature_fraction=0.992; bagging_fraction=0.979; max_depth=4; min_sum_hessian_in_leaf=0.0638; lambda_l1=4.01; lambda_l2=4.21; min_gain_to_split=0.0718; min_data_in_bin=3; max_bin=210; scale_pos_weight=2.15 : y = 0.928 : 10.1 secs : infill_ei
#
# Thu Jul 31 16:01:47 2025 AUC 0.929786252585067
#
# [mbo] 26: num_leaves=17; min_data_in_leaf=42; learning_rate=0.0922; feature_fraction=0.975; bagging_fraction=0.965; max_depth=6; min_sum_hessian_in_leaf=0.0188; lambda_l1=2.04; lambda_l2=1.91; min_gain_to_split=0.0398; min_data_in_bin=4; max_bin=98; scale_pos_weight=0.517 : y = 0.93 : 9.6 secs : infill_ei
#
# Thu Jul 31 16:01:57 2025 AUC 0.930069147200692
#
# [mbo] 27: num_leaves=13; min_data_in_leaf=33; learning_rate=0.108; feature_fraction=0.943; bagging_fraction=0.999; max_depth=5; min_sum_hessian_in_leaf=0.0463; lambda_l1=4.23; lambda_l2=2.3; min_gain_to_split=0.0487; min_data_in_bin=6; max_bin=81; scale_pos_weight=0.708 : y = 0.93 : 7.2 secs : infill_ei
#
# Thu Jul 31 16:02:09 2025 AUC 0.929686373067337
#
# [mbo] 28: num_leaves=18; min_data_in_leaf=23; learning_rate=0.0869; feature_fraction=0.894; bagging_fraction=0.94; max_depth=3; min_sum_hessian_in_leaf=0.0312; lambda_l1=3.28; lambda_l2=4.05; min_gain_to_split=0.0301; min_data_in_bin=3; max_bin=178; scale_pos_weight=0.769 : y = 0.93 : 10.0 secs : infill_ei
#
# Thu Jul 31 16:02:19 2025 AUC 0.929528333317845
#
# [mbo] 29: num_leaves=12; min_data_in_leaf=38; learning_rate=0.104; feature_fraction=0.936; bagging_fraction=0.925; max_depth=6; min_sum_hessian_in_leaf=0.0256; lambda_l1=3.98; lambda_l2=4.37; min_gain_to_split=0.0433; min_data_in_bin=9; max_bin=89; scale_pos_weight=0.673 : y = 0.93 : 7.7 secs : infill_ei
#
# Thu Jul 31 16:02:33 2025 AUC 0.930452258759334
#
# [mbo] 30: num_leaves=45; min_data_in_leaf=22; learning_rate=0.0641; feature_fraction=0.865; bagging_fraction=0.968; max_depth=4; min_sum_hessian_in_leaf=0.0318; lambda_l1=1.9; lambda_l2=3.66; min_gain_to_split=0.0547; min_data_in_bin=3; max_bin=104; scale_pos_weight=0.503 : y = 0.93 : 12.0 secs : infill_ei
#
# Thu Jul 31 16:02:46 2025 AUC 0.929642958790672
#
# [mbo] 31: num_leaves=62; min_data_in_leaf=35; learning_rate=0.0575; feature_fraction=0.879; bagging_fraction=0.973; max_depth=4; min_sum_hessian_in_leaf=0.0574; lambda_l1=2.81; lambda_l2=3.54; min_gain_to_split=0.0516; min_data_in_bin=2; max_bin=127; scale_pos_weight=0.78 : y = 0.93 : 11.0 secs : infill_ei
#
# Thu Jul 31 16:03:00 2025 AUC 0.929284066344649
#
# [mbo] 32: num_leaves=30; min_data_in_leaf=29; learning_rate=0.0804; feature_fraction=0.907; bagging_fraction=0.984; max_depth=4; min_sum_hessian_in_leaf=0.0346; lambda_l1=1.99; lambda_l2=4.51; min_gain_to_split=0.0558; min_data_in_bin=2; max_bin=106; scale_pos_weight=0.618 : y = 0.929 : 10.9 secs : infill_ei
#
# Thu Jul 31 16:03:13 2025 AUC 0.929531998262284
#
# [mbo] 33: num_leaves=45; min_data_in_leaf=41; learning_rate=0.0641; feature_fraction=0.856; bagging_fraction=0.995; max_depth=5; min_sum_hessian_in_leaf=0.0655; lambda_l1=1.23; lambda_l2=1.63; min_gain_to_split=0.0437; min_data_in_bin=4; max_bin=117; scale_pos_weight=0.625 : y = 0.93 : 11.5 secs : infill_ei
#
# Thu Jul 31 16:03:25 2025 AUC 0.929125931776432
#
# [mbo] 34: num_leaves=11; min_data_in_leaf=29; learning_rate=0.097; feature_fraction=0.962; bagging_fraction=0.857; max_depth=3; min_sum_hessian_in_leaf=0.0274; lambda_l1=2.97; lambda_l2=3.17; min_gain_to_split=0.0489; min_data_in_bin=4; max_bin=111; scale_pos_weight=0.746 : y = 0.929 : 9.3 secs : infill_ei
#
# Thu Jul 31 16:03:38 2025 AUC 0.929265247986488
#
# [mbo] 35: num_leaves=27; min_data_in_leaf=39; learning_rate=0.0818; feature_fraction=0.945; bagging_fraction=0.951; max_depth=5; min_sum_hessian_in_leaf=0.00322; lambda_l1=3.28; lambda_l2=3.02; min_gain_to_split=0.0426; min_data_in_bin=5; max_bin=86; scale_pos_weight=0.554 : y = 0.929 : 11.3 secs : infill_ei
#
# Thu Jul 31 16:03:52 2025 AUC 0.929476964464332
#
# [mbo] 36: num_leaves=48; min_data_in_leaf=25; learning_rate=0.0589; feature_fraction=0.981; bagging_fraction=0.924; max_depth=4; min_sum_hessian_in_leaf=0.0244; lambda_l1=3.79; lambda_l2=4.47; min_gain_to_split=0.071; min_data_in_bin=7; max_bin=111; scale_pos_weight=0.933 : y = 0.929 : 11.3 secs : infill_ei
#
# Thu Jul 31 16:04:06 2025 AUC 0.928835613473872
#
# [mbo] 37: num_leaves=47; min_data_in_leaf=33; learning_rate=0.0566; feature_fraction=0.811; bagging_fraction=0.899; max_depth=4; min_sum_hessian_in_leaf=0.00802; lambda_l1=1.05; lambda_l2=3.27; min_gain_to_split=0.0512; min_data_in_bin=3; max_bin=108; scale_pos_weight=0.676 : y = 0.929 : 11.1 secs : infill_ei
#
# Thu Jul 31 16:04:21 2025 AUC 0.930676256634846
#
# [mbo] 38: num_leaves=13; min_data_in_leaf=18; learning_rate=0.0653; feature_fraction=0.918; bagging_fraction=0.99; max_depth=5; min_sum_hessian_in_leaf=0.0841; lambda_l1=3.68; lambda_l2=1.48; min_gain_to_split=0.0542; min_data_in_bin=3; max_bin=131; scale_pos_weight=0.535 : y = 0.931 : 12.7 secs : infill_ei
#
# Thu Jul 31 16:04:36 2025 AUC 0.930030783082416
#
# [mbo] 39: num_leaves=43; min_data_in_leaf=13; learning_rate=0.0678; feature_fraction=0.875; bagging_fraction=0.964; max_depth=4; min_sum_hessian_in_leaf=0.0834; lambda_l1=3.3; lambda_l2=4.26; min_gain_to_split=0.0497; min_data_in_bin=3; max_bin=201; scale_pos_weight=0.605 : y = 0.93 : 12.9 secs : infill_ei
#
# Thu Jul 31 16:04:51 2025 AUC 0.930103279167722
#
# [mbo] 40: num_leaves=39; min_data_in_leaf=20; learning_rate=0.062; feature_fraction=0.855; bagging_fraction=0.953; max_depth=4; min_sum_hessian_in_leaf=0.0982; lambda_l1=3.46; lambda_l2=1.05; min_gain_to_split=0.0708; min_data_in_bin=3; max_bin=149; scale_pos_weight=0.517 : y = 0.93 : 12.9 secs : infill_ei
#
# Thu Jul 31 16:05:07 2025 AUC 0.930043822068863
#
# [mbo] 41: num_leaves=26; min_data_in_leaf=22; learning_rate=0.0639; feature_fraction=0.928; bagging_fraction=0.992; max_depth=4; min_sum_hessian_in_leaf=0.0448; lambda_l1=3.21; lambda_l2=2.71; min_gain_to_split=0.031; min_data_in_bin=3; max_bin=226; scale_pos_weight=0.639 : y = 0.93 : 13.5 secs : infill_ei
#
# Thu Jul 31 16:05:20 2025 AUC 0.929123486999479
#
# [mbo] 42: num_leaves=48; min_data_in_leaf=14; learning_rate=0.0626; feature_fraction=0.858; bagging_fraction=0.968; max_depth=5; min_sum_hessian_in_leaf=0.0491; lambda_l1=2.98; lambda_l2=3.24; min_gain_to_split=0.0562; min_data_in_bin=4; max_bin=117; scale_pos_weight=0.53 : y = 0.929 : 10.3 secs : infill_ei
#
# Thu Jul 31 16:05:32 2025 AUC 0.929855524950846
#
# [mbo] 43: num_leaves=28; min_data_in_leaf=19; learning_rate=0.0662; feature_fraction=0.867; bagging_fraction=0.988; max_depth=3; min_sum_hessian_in_leaf=0.0361; lambda_l1=0.188; lambda_l2=3.23; min_gain_to_split=0.0955; min_data_in_bin=3; max_bin=145; scale_pos_weight=0.545 : y = 0.93 : 9.6 secs : infill_ei
#
# Thu Jul 31 16:05:47 2025 AUC 0.929497079708196
#
# [mbo] 44: num_leaves=12; min_data_in_leaf=33; learning_rate=0.0728; feature_fraction=0.956; bagging_fraction=0.983; max_depth=5; min_sum_hessian_in_leaf=0.0969; lambda_l1=2.38; lambda_l2=0.759; min_gain_to_split=0.0464; min_data_in_bin=3; max_bin=158; scale_pos_weight=0.514 : y = 0.929 : 12.3 secs : infill_ei
#
# Thu Jul 31 16:05:59 2025 AUC 0.928346189029398
#
# [mbo] 45: num_leaves=19; min_data_in_leaf=9; learning_rate=0.0663; feature_fraction=0.926; bagging_fraction=0.971; max_depth=3; min_sum_hessian_in_leaf=0.0865; lambda_l1=3.8; lambda_l2=3.73; min_gain_to_split=0.0541; min_data_in_bin=4; max_bin=115; scale_pos_weight=2.78 : y = 0.928 : 9.7 secs : infill_ei
#
# Thu Jul 31 16:06:12 2025 AUC 0.92939320993617
#
# [mbo] 46: num_leaves=27; min_data_in_leaf=21; learning_rate=0.0652; feature_fraction=0.906; bagging_fraction=0.904; max_depth=4; min_sum_hessian_in_leaf=0.0926; lambda_l1=3.88; lambda_l2=1.78; min_gain_to_split=0.0709; min_data_in_bin=2; max_bin=141; scale_pos_weight=0.536 : y = 0.929 : 11.0 secs : infill_ei
#
# Thu Jul 31 16:06:27 2025 AUC 0.929227821472114
#
# [mbo] 47: num_leaves=12; min_data_in_leaf=23; learning_rate=0.0621; feature_fraction=0.872; bagging_fraction=0.999; max_depth=5; min_sum_hessian_in_leaf=0.0415; lambda_l1=4.02; lambda_l2=3.79; min_gain_to_split=0.0299; min_data_in_bin=3; max_bin=125; scale_pos_weight=0.64 : y = 0.929 : 12.3 secs : infill_ei
#
# Thu Jul 31 16:06:39 2025 AUC 0.929213881024948
#
# [mbo] 48: num_leaves=21; min_data_in_leaf=29; learning_rate=0.0944; feature_fraction=0.889; bagging_fraction=0.951; max_depth=4; min_sum_hessian_in_leaf=0.0358; lambda_l1=1.39; lambda_l2=2.52; min_gain_to_split=0.0547; min_data_in_bin=6; max_bin=218; scale_pos_weight=0.721 : y = 0.929 : 8.7 secs : infill_ei
#
# Thu Jul 31 16:06:50 2025 AUC 0.928835305818964
#
# [mbo] 49: num_leaves=15; min_data_in_leaf=18; learning_rate=0.0651; feature_fraction=0.97; bagging_fraction=0.983; max_depth=4; min_sum_hessian_in_leaf=0.0867; lambda_l1=2.65; lambda_l2=1.34; min_gain_to_split=0.0395; min_data_in_bin=3; max_bin=109; scale_pos_weight=0.677 : y = 0.929 : 8.8 secs : infill_ei
#
# Thu Jul 31 16:07:00 2025 AUC 0.928946546691825
#
# [mbo] 50: num_leaves=11; min_data_in_leaf=47; learning_rate=0.107; feature_fraction=0.98; bagging_fraction=0.939; max_depth=5; min_sum_hessian_in_leaf=0.0113; lambda_l1=4.45; lambda_l2=2.02; min_gain_to_split=0.0856; min_data_in_bin=8; max_bin=99; scale_pos_weight=0.547 : y = 0.929 : 7.5 secs : infill_ei
#
# Thu Jul 31 16:07:14 2025 AUC 0.92886740503096
#
# [mbo] 51: num_leaves=10; min_data_in_leaf=30; learning_rate=0.0836; feature_fraction=0.982; bagging_fraction=0.968; max_depth=5; min_sum_hessian_in_leaf=0.0877; lambda_l1=3.66; lambda_l2=2.37; min_gain_to_split=0.0362; min_data_in_bin=6; max_bin=121; scale_pos_weight=0.771 : y = 0.929 : 11.3 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Thu Jul 31 16:07:34 2025 AUC 0.929050557498501
#
# [mbo] 52: num_leaves=11; min_data_in_leaf=14; learning_rate=0.0611; feature_fraction=0.925; bagging_fraction=0.949; max_depth=5; min_sum_hessian_in_leaf=0.0779; lambda_l1=3.99; lambda_l2=1.97; min_gain_to_split=0.0633; min_data_in_bin=7; max_bin=154; scale_pos_weight=0.511 : y = 0.929 : 12.3 secs : infill_ei
#
# Thu Jul 31 16:07:47 2025 AUC 0.929945933453198
#
# [mbo] 53: num_leaves=46; min_data_in_leaf=22; learning_rate=0.067; feature_fraction=0.874; bagging_fraction=0.961; max_depth=3; min_sum_hessian_in_leaf=0.0246; lambda_l1=2.37; lambda_l2=2.98; min_gain_to_split=0.0404; min_data_in_bin=2; max_bin=175; scale_pos_weight=0.518 : y = 0.93 : 10.1 secs : infill_ei
#
# Thu Jul 31 16:07:59 2025 AUC 0.929404260379895
#
# [mbo] 54: num_leaves=42; min_data_in_leaf=22; learning_rate=0.0605; feature_fraction=0.861; bagging_fraction=0.969; max_depth=3; min_sum_hessian_in_leaf=0.0966; lambda_l1=0.826; lambda_l2=4.71; min_gain_to_split=0.0414; min_data_in_bin=2; max_bin=104; scale_pos_weight=0.633 : y = 0.929 : 9.1 secs : infill_ei
#
# Thu Jul 31 16:08:13 2025 AUC 0.929143443845002
#
# [mbo] 55: num_leaves=26; min_data_in_leaf=8; learning_rate=0.0654; feature_fraction=0.912; bagging_fraction=0.97; max_depth=6; min_sum_hessian_in_leaf=0.026; lambda_l1=4; lambda_l2=1.29; min_gain_to_split=0.0594; min_data_in_bin=3; max_bin=135; scale_pos_weight=0.52 : y = 0.929 : 11.2 secs : infill_ei
#
# Thu Jul 31 16:08:24 2025 AUC 0.928613879031156
#
# [mbo] 56: num_leaves=47; min_data_in_leaf=26; learning_rate=0.0624; feature_fraction=0.864; bagging_fraction=0.96; max_depth=3; min_sum_hessian_in_leaf=0.0165; lambda_l1=1.38; lambda_l2=1.07; min_gain_to_split=0.0808; min_data_in_bin=3; max_bin=88; scale_pos_weight=0.619 : y = 0.929 : 8.8 secs : infill_ei
#
# Thu Jul 31 16:08:41 2025 AUC 0.92947226397872
#
# [mbo] 57: num_leaves=17; min_data_in_leaf=17; learning_rate=0.0528; feature_fraction=0.92; bagging_fraction=0.998; max_depth=5; min_sum_hessian_in_leaf=0.0975; lambda_l1=3.5; lambda_l2=0.901; min_gain_to_split=0.0754; min_data_in_bin=1; max_bin=115; scale_pos_weight=0.572 : y = 0.929 : 13.5 secs : infill_ei
#
# Thu Jul 31 16:08:55 2025 AUC 0.92955027982172
#
# [mbo] 58: num_leaves=57; min_data_in_leaf=22; learning_rate=0.0667; feature_fraction=0.857; bagging_fraction=0.993; max_depth=4; min_sum_hessian_in_leaf=0.0452; lambda_l1=1.75; lambda_l2=4.41; min_gain_to_split=0.0562; min_data_in_bin=3; max_bin=173; scale_pos_weight=1.04 : y = 0.93 : 11.6 secs : infill_ei
#
# Thu Jul 31 16:09:11 2025 AUC 0.929489970589745
#
# [mbo] 59: num_leaves=17; min_data_in_leaf=33; learning_rate=0.0623; feature_fraction=0.88; bagging_fraction=0.967; max_depth=4; min_sum_hessian_in_leaf=0.0552; lambda_l1=4.25; lambda_l2=1.92; min_gain_to_split=0.0566; min_data_in_bin=3; max_bin=198; scale_pos_weight=0.577 : y = 0.929 : 12.8 secs : infill_ei
#
# Thu Jul 31 16:09:26 2025 AUC 0.930318992768298
#
# [mbo] 60: num_leaves=45; min_data_in_leaf=21; learning_rate=0.0678; feature_fraction=0.948; bagging_fraction=0.995; max_depth=4; min_sum_hessian_in_leaf=0.0343; lambda_l1=2.9; lambda_l2=3.84; min_gain_to_split=0.0899; min_data_in_bin=3; max_bin=143; scale_pos_weight=0.511 : y = 0.93 : 11.9 secs : infill_ei
#
# Thu Jul 31 16:09:40 2025 AUC 0.92959502633363
#
# [mbo] 61: num_leaves=42; min_data_in_leaf=18; learning_rate=0.0623; feature_fraction=0.917; bagging_fraction=0.955; max_depth=3; min_sum_hessian_in_leaf=0.0484; lambda_l1=1.62; lambda_l2=3.75; min_gain_to_split=0.0429; min_data_in_bin=3; max_bin=216; scale_pos_weight=0.537 : y = 0.93 : 11.6 secs : infill_ei
#
# Thu Jul 31 16:09:52 2025 AUC 0.929805259256667
#
# [mbo] 62: num_leaves=11; min_data_in_leaf=34; learning_rate=0.103; feature_fraction=0.899; bagging_fraction=0.999; max_depth=5; min_sum_hessian_in_leaf=0.0435; lambda_l1=2.3; lambda_l2=1.56; min_gain_to_split=0.0241; min_data_in_bin=3; max_bin=153; scale_pos_weight=0.571 : y = 0.93 : 8.7 secs : infill_ei
#
# Thu Jul 31 16:10:08 2025 AUC 0.929055374883361
#
# [mbo] 63: num_leaves=74; min_data_in_leaf=15; learning_rate=0.0691; feature_fraction=0.917; bagging_fraction=0.985; max_depth=5; min_sum_hessian_in_leaf=0.0584; lambda_l1=2.52; lambda_l2=0.633; min_gain_to_split=0.0187; min_data_in_bin=2; max_bin=200; scale_pos_weight=0.512 : y = 0.929 : 13.7 secs : infill_ei
#
# Thu Jul 31 16:10:27 2025 AUC 0.930566816334436
#
# [mbo] 64: num_leaves=18; min_data_in_leaf=11; learning_rate=0.0274; feature_fraction=0.931; bagging_fraction=0.971; max_depth=8; min_sum_hessian_in_leaf=0.045; lambda_l1=2.13; lambda_l2=3.92; min_gain_to_split=0.0306; min_data_in_bin=8; max_bin=139; scale_pos_weight=4.29 : y = 0.931 : 15.4 secs : infill_ei
#
# Thu Jul 31 16:10:48 2025 AUC 0.929226145334393
#
# [mbo] 65: num_leaves=21; min_data_in_leaf=18; learning_rate=0.0246; feature_fraction=0.915; bagging_fraction=0.964; max_depth=8; min_sum_hessian_in_leaf=0.0291; lambda_l1=3.26; lambda_l2=4.65; min_gain_to_split=0.0403; min_data_in_bin=7; max_bin=117; scale_pos_weight=4.69 : y = 0.929 : 17.8 secs : infill_ei
#
# Thu Jul 31 16:11:03 2025 AUC 0.928762301751778
#
# [mbo] 66: num_leaves=10; min_data_in_leaf=20; learning_rate=0.022; feature_fraction=0.906; bagging_fraction=0.994; max_depth=8; min_sum_hessian_in_leaf=0.0613; lambda_l1=1.94; lambda_l2=1.57; min_gain_to_split=0.0425; min_data_in_bin=9; max_bin=118; scale_pos_weight=4.42 : y = 0.929 : 12.4 secs : infill_ei
#
# Thu Jul 31 16:11:23 2025 AUC 0.930184876924502
#
# [mbo] 67: num_leaves=20; min_data_in_leaf=6; learning_rate=0.0337; feature_fraction=0.935; bagging_fraction=0.879; max_depth=7; min_sum_hessian_in_leaf=0.0659; lambda_l1=3.7; lambda_l2=4.72; min_gain_to_split=0.0243; min_data_in_bin=9; max_bin=157; scale_pos_weight=4.26 : y = 0.93 : 17.0 secs : infill_ei
#
# Thu Jul 31 16:11:40 2025 AUC 0.929128327130581
#
# [mbo] 68: num_leaves=19; min_data_in_leaf=12; learning_rate=0.0357; feature_fraction=0.945; bagging_fraction=0.897; max_depth=8; min_sum_hessian_in_leaf=0.0373; lambda_l1=0.609; lambda_l2=4.1; min_gain_to_split=0.0765; min_data_in_bin=9; max_bin=182; scale_pos_weight=4.06 : y = 0.929 : 13.7 secs : infill_ei
#
# Thu Jul 31 16:11:59 2025 AUC 0.93049309410982
#
# [mbo] 69: num_leaves=17; min_data_in_leaf=5; learning_rate=0.0306; feature_fraction=0.934; bagging_fraction=0.992; max_depth=7; min_sum_hessian_in_leaf=0.0764; lambda_l1=2.85; lambda_l2=4.36; min_gain_to_split=0.0171; min_data_in_bin=8; max_bin=139; scale_pos_weight=4.23 : y = 0.93 : 15.4 secs : infill_ei
#
# Thu Jul 31 16:12:25 2025 AUC 0.928103919668736
#
# [mbo] 70: num_leaves=53; min_data_in_leaf=4; learning_rate=0.0273; feature_fraction=0.916; bagging_fraction=0.93; max_depth=8; min_sum_hessian_in_leaf=0.0905; lambda_l1=2.72; lambda_l2=3.88; min_gain_to_split=0.00914; min_data_in_bin=8; max_bin=205; scale_pos_weight=4.07 : y = 0.928 : 22.2 secs : infill_ei
#
# Thu Jul 31 16:12:37 2025 AUC 0.929850584333387
#
# [mbo] 71: num_leaves=11; min_data_in_leaf=22; learning_rate=0.0938; feature_fraction=0.938; bagging_fraction=0.996; max_depth=5; min_sum_hessian_in_leaf=0.0281; lambda_l1=2.6; lambda_l2=3.97; min_gain_to_split=0.0646; min_data_in_bin=3; max_bin=137; scale_pos_weight=0.517 : y = 0.93 : 9.5 secs : infill_ei
#
# Thu Jul 31 16:12:53 2025 AUC 0.929563110536274
#
# [mbo] 72: num_leaves=54; min_data_in_leaf=23; learning_rate=0.0677; feature_fraction=0.946; bagging_fraction=0.889; max_depth=4; min_sum_hessian_in_leaf=0.0302; lambda_l1=4.36; lambda_l2=4.61; min_gain_to_split=0.0197; min_data_in_bin=2; max_bin=141; scale_pos_weight=0.5 : y = 0.93 : 12.0 secs : infill_ei
#
# Thu Jul 31 16:13:08 2025 AUC 0.928140071680658
#
# [mbo] 73: num_leaves=10; min_data_in_leaf=31; learning_rate=0.0758; feature_fraction=0.92; bagging_fraction=0.982; max_depth=6; min_sum_hessian_in_leaf=0.0759; lambda_l1=4.44; lambda_l2=1.36; min_gain_to_split=0.0313; min_data_in_bin=3; max_bin=147; scale_pos_weight=0.501 : y = 0.928 : 12.1 secs : infill_ei
#
# Thu Jul 31 16:13:25 2025 AUC 0.930005828305986
#
# [mbo] 74: num_leaves=21; min_data_in_leaf=10; learning_rate=0.0324; feature_fraction=0.952; bagging_fraction=0.967; max_depth=7; min_sum_hessian_in_leaf=0.0352; lambda_l1=1.91; lambda_l2=4.14; min_gain_to_split=0.0208; min_data_in_bin=8; max_bin=106; scale_pos_weight=4.21 : y = 0.93 : 13.5 secs : infill_ei
#
# Thu Jul 31 16:13:36 2025 AUC 0.928468582379304
#
# [mbo] 75: num_leaves=22; min_data_in_leaf=37; learning_rate=0.1; feature_fraction=0.882; bagging_fraction=0.996; max_depth=5; min_sum_hessian_in_leaf=0.0649; lambda_l1=0.497; lambda_l2=1.27; min_gain_to_split=0.0659; min_data_in_bin=6; max_bin=127; scale_pos_weight=0.683 : y = 0.928 : 7.7 secs : infill_ei
#
# Thu Jul 31 16:13:53 2025 AUC 0.929586063979367
#
# [mbo] 76: num_leaves=10; min_data_in_leaf=3; learning_rate=0.0305; feature_fraction=0.937; bagging_fraction=0.991; max_depth=8; min_sum_hessian_in_leaf=0.0182; lambda_l1=3.14; lambda_l2=3.73; min_gain_to_split=0.00901; min_data_in_bin=8; max_bin=196; scale_pos_weight=4.26 : y = 0.93 : 13.9 secs : infill_ei
#
# Thu Jul 31 16:14:04 2025 AUC 0.929709573205243
#
# [mbo] 77: num_leaves=18; min_data_in_leaf=35; learning_rate=0.106; feature_fraction=0.95; bagging_fraction=0.968; max_depth=4; min_sum_hessian_in_leaf=0.0213; lambda_l1=4.72; lambda_l2=0.686; min_gain_to_split=0.0279; min_data_in_bin=4; max_bin=151; scale_pos_weight=0.798 : y = 0.93 : 7.3 secs : infill_ei
#
# Thu Jul 31 16:14:24 2025 AUC 0.929516527769394
#
# [mbo] 78: num_leaves=18; min_data_in_leaf=13; learning_rate=0.0315; feature_fraction=0.945; bagging_fraction=0.99; max_depth=7; min_sum_hessian_in_leaf=0.077; lambda_l1=4.01; lambda_l2=4.38; min_gain_to_split=0.0295; min_data_in_bin=9; max_bin=159; scale_pos_weight=3.85 : y = 0.93 : 16.1 secs : infill_ei
#
# Thu Jul 31 16:14:40 2025 AUC 0.929753174657401
#
# [mbo] 79: num_leaves=17; min_data_in_leaf=3; learning_rate=0.0323; feature_fraction=0.943; bagging_fraction=0.981; max_depth=8; min_sum_hessian_in_leaf=0.0722; lambda_l1=1.98; lambda_l2=4.44; min_gain_to_split=0.0435; min_data_in_bin=10; max_bin=136; scale_pos_weight=4.51 : y = 0.93 : 12.8 secs : infill_ei
#
# Thu Jul 31 16:14:59 2025 AUC 0.929971202856025
#
# [mbo] 80: num_leaves=25; min_data_in_leaf=14; learning_rate=0.0282; feature_fraction=0.932; bagging_fraction=0.952; max_depth=7; min_sum_hessian_in_leaf=0.0222; lambda_l1=1.45; lambda_l2=4.81; min_gain_to_split=0.0569; min_data_in_bin=7; max_bin=99; scale_pos_weight=4.23 : y = 0.93 : 15.2 secs : infill_ei
#
# Thu Jul 31 16:15:17 2025 AUC 0.929312138368272
#
# [mbo] 81: num_leaves=18; min_data_in_leaf=16; learning_rate=0.0278; feature_fraction=0.916; bagging_fraction=0.845; max_depth=7; min_sum_hessian_in_leaf=0.0494; lambda_l1=0.953; lambda_l2=3.9; min_gain_to_split=0.0301; min_data_in_bin=7; max_bin=123; scale_pos_weight=4.16 : y = 0.929 : 14.3 secs : infill_ei
#
# Thu Jul 31 16:15:30 2025 AUC 0.930193384376527
#
# [mbo] 82: num_leaves=14; min_data_in_leaf=34; learning_rate=0.0856; feature_fraction=0.864; bagging_fraction=0.932; max_depth=4; min_sum_hessian_in_leaf=0.016; lambda_l1=2.69; lambda_l2=4.63; min_gain_to_split=0.0166; min_data_in_bin=2; max_bin=105; scale_pos_weight=0.548 : y = 0.93 : 9.7 secs : infill_ei
# ...
#
# [mbo] 356: num_leaves=76; min_data_in_leaf=26; learning_rate=0.0302; feature_fraction=0.862; bagging_fraction=0.928; max_depth=8; min_sum_hessian_in_leaf=0.0428; lambda_l1=3.58; lambda_l2=3.71; min_gain_to_split=0.0128; min_data_in_bin=8; max_bin=142; scale_pos_weight=3.06 : y = 0.928 : 23.6 secs : infill_ei
#
# Thu Jul 31 18:19:56 2025 AUC 0.931378872203178
#
# [mbo] 357: num_leaves=14; min_data_in_leaf=33; learning_rate=0.0275; feature_fraction=0.868; bagging_fraction=0.978; max_depth=7; min_sum_hessian_in_leaf=0.0636; lambda_l1=1.44; lambda_l2=4.44; min_gain_to_split=0.0765; min_data_in_bin=8; max_bin=104; scale_pos_weight=4.78 : y = 0.931 : 13.2 secs : infill_ei
#
# Thu Jul 31 18:20:34 2025 AUC 0.93036357559076
#
# [mbo] 358: num_leaves=18; min_data_in_leaf=18; learning_rate=0.0285; feature_fraction=0.87; bagging_fraction=0.968; max_depth=7; min_sum_hessian_in_leaf=0.0539; lambda_l1=3.15; lambda_l2=4.43; min_gain_to_split=0.0433; min_data_in_bin=8; max_bin=141; scale_pos_weight=4.25 : y = 0.93 : 15.9 secs : infill_ei
#
# Thu Jul 31 18:21:09 2025 AUC 0.929936941176085
#
# [mbo] 359: num_leaves=66; min_data_in_leaf=18; learning_rate=0.0704; feature_fraction=0.833; bagging_fraction=0.909; max_depth=4; min_sum_hessian_in_leaf=0.0504; lambda_l1=2.85; lambda_l2=4.08; min_gain_to_split=0.0232; min_data_in_bin=6; max_bin=219; scale_pos_weight=0.718 : y = 0.93 : 14.5 secs : infill_ei
#
# Thu Jul 31 18:21:44 2025 AUC 0.92971379374777
#
# [mbo] 360: num_leaves=14; min_data_in_leaf=40; learning_rate=0.0285; feature_fraction=0.839; bagging_fraction=0.911; max_depth=8; min_sum_hessian_in_leaf=0.0756; lambda_l1=0.443; lambda_l2=4.84; min_gain_to_split=0.0217; min_data_in_bin=4; max_bin=159; scale_pos_weight=4.15 : y = 0.93 : 14.1 secs : infill_ei
#
# Thu Jul 31 18:22:25 2025 AUC 0.929341401990095
#
# [mbo] 361: num_leaves=27; min_data_in_leaf=34; learning_rate=0.0272; feature_fraction=0.867; bagging_fraction=0.925; max_depth=8; min_sum_hessian_in_leaf=0.042; lambda_l1=2.17; lambda_l2=4.39; min_gain_to_split=0.0126; min_data_in_bin=10; max_bin=167; scale_pos_weight=4.01 : y = 0.929 : 20.4 secs : infill_ei
#
# Saved the current state after iteration 362 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:23:06 2025 AUC 0.929624341352076
#
# [mbo] 362: num_leaves=21; min_data_in_leaf=24; learning_rate=0.0327; feature_fraction=0.86; bagging_fraction=0.971; max_depth=7; min_sum_hessian_in_leaf=0.0165; lambda_l1=2.32; lambda_l2=4.19; min_gain_to_split=0.0778; min_data_in_bin=8; max_bin=119; scale_pos_weight=4.69 : y = 0.93 : 12.1 secs : infill_ei
#
# Thu Jul 31 18:23:41 2025 AUC 0.929137359814777
#
# [mbo] 363: num_leaves=29; min_data_in_leaf=17; learning_rate=0.0715; feature_fraction=0.888; bagging_fraction=0.95; max_depth=5; min_sum_hessian_in_leaf=0.0861; lambda_l1=2.55; lambda_l2=3.26; min_gain_to_split=0.0435; min_data_in_bin=7; max_bin=179; scale_pos_weight=0.86 : y = 0.929 : 13.6 secs : infill_ei
#
# Thu Jul 31 18:24:23 2025 AUC 0.929905342683093
#
# [mbo] 364: num_leaves=19; min_data_in_leaf=22; learning_rate=0.0305; feature_fraction=0.864; bagging_fraction=0.876; max_depth=8; min_sum_hessian_in_leaf=0.0845; lambda_l1=2.71; lambda_l2=4.54; min_gain_to_split=0.0223; min_data_in_bin=9; max_bin=214; scale_pos_weight=4.18 : y = 0.93 : 19.9 secs : infill_ei
#
# Thu Jul 31 18:25:08 2025 AUC 0.930049417278793
#
# [mbo] 365: num_leaves=41; min_data_in_leaf=43; learning_rate=0.0301; feature_fraction=0.879; bagging_fraction=0.879; max_depth=8; min_sum_hessian_in_leaf=0.0257; lambda_l1=2.33; lambda_l2=4.69; min_gain_to_split=0.0102; min_data_in_bin=3; max_bin=223; scale_pos_weight=3.74 : y = 0.93 : 22.4 secs : infill_ei
#
# Thu Jul 31 18:25:45 2025 AUC 0.93021326100514
#
# [mbo] 366: num_leaves=11; min_data_in_leaf=40; learning_rate=0.0329; feature_fraction=0.957; bagging_fraction=0.955; max_depth=8; min_sum_hessian_in_leaf=0.05; lambda_l1=2.92; lambda_l2=3.65; min_gain_to_split=0.0338; min_data_in_bin=5; max_bin=143; scale_pos_weight=3.65 : y = 0.93 : 13.4 secs : infill_ei
#
# Thu Jul 31 18:26:20 2025 AUC 0.930663851759564
#
# [mbo] 367: num_leaves=15; min_data_in_leaf=38; learning_rate=0.0397; feature_fraction=0.874; bagging_fraction=0.945; max_depth=7; min_sum_hessian_in_leaf=0.0203; lambda_l1=2.57; lambda_l2=3.56; min_gain_to_split=0.0158; min_data_in_bin=5; max_bin=170; scale_pos_weight=4.84 : y = 0.931 : 13.4 secs : infill_ei
#
# Thu Jul 31 18:26:53 2025 AUC 0.930015022560443
#
# [mbo] 368: num_leaves=25; min_data_in_leaf=39; learning_rate=0.0673; feature_fraction=0.838; bagging_fraction=0.958; max_depth=4; min_sum_hessian_in_leaf=0.00561; lambda_l1=3; lambda_l2=1.48; min_gain_to_split=0.0975; min_data_in_bin=4; max_bin=182; scale_pos_weight=0.765 : y = 0.93 : 10.6 secs : infill_ei
#
# Thu Jul 31 18:27:27 2025 AUC 0.92936941786889
#
# [mbo] 369: num_leaves=14; min_data_in_leaf=39; learning_rate=0.0282; feature_fraction=0.906; bagging_fraction=0.959; max_depth=7; min_sum_hessian_in_leaf=0.0957; lambda_l1=2.86; lambda_l2=3.86; min_gain_to_split=0.0187; min_data_in_bin=9; max_bin=104; scale_pos_weight=4.44 : y = 0.929 : 13.5 secs : infill_ei
#
# Thu Jul 31 18:28:05 2025 AUC 0.930231445322805
#
# [mbo] 370: num_leaves=26; min_data_in_leaf=7; learning_rate=0.0678; feature_fraction=0.833; bagging_fraction=0.93; max_depth=6; min_sum_hessian_in_leaf=0.0233; lambda_l1=2.19; lambda_l2=4.25; min_gain_to_split=0.0773; min_data_in_bin=6; max_bin=225; scale_pos_weight=0.668 : y = 0.93 : 14.6 secs : infill_ei
#
# Thu Jul 31 18:28:47 2025 AUC 0.92915985935671
#
# [mbo] 371: num_leaves=26; min_data_in_leaf=25; learning_rate=0.0331; feature_fraction=0.883; bagging_fraction=0.921; max_depth=8; min_sum_hessian_in_leaf=0.0309; lambda_l1=2.39; lambda_l2=4.7; min_gain_to_split=0.0131; min_data_in_bin=4; max_bin=211; scale_pos_weight=3.58 : y = 0.929 : 21.0 secs : infill_ei
#
# Thu Jul 31 18:29:34 2025 AUC 0.92973822365182
#
# [mbo] 372: num_leaves=38; min_data_in_leaf=44; learning_rate=0.0284; feature_fraction=0.879; bagging_fraction=0.89; max_depth=8; min_sum_hessian_in_leaf=0.0183; lambda_l1=1.76; lambda_l2=4.84; min_gain_to_split=0.0315; min_data_in_bin=3; max_bin=190; scale_pos_weight=4.06 : y = 0.93 : 22.3 secs : infill_ei
#
# Thu Jul 31 18:30:10 2025 AUC 0.930250181467662
#
# [mbo] 373: num_leaves=16; min_data_in_leaf=7; learning_rate=0.0274; feature_fraction=0.849; bagging_fraction=0.973; max_depth=7; min_sum_hessian_in_leaf=0.0416; lambda_l1=3.59; lambda_l2=4.16; min_gain_to_split=0.0863; min_data_in_bin=8; max_bin=80; scale_pos_weight=3.55 : y = 0.93 : 13.8 secs : infill_ei
#
# Thu Jul 31 18:30:47 2025 AUC 0.929037989679557
#
# [mbo] 374: num_leaves=13; min_data_in_leaf=34; learning_rate=0.0267; feature_fraction=0.976; bagging_fraction=0.886; max_depth=8; min_sum_hessian_in_leaf=0.0816; lambda_l1=1.22; lambda_l2=2.22; min_gain_to_split=0.0694; min_data_in_bin=8; max_bin=86; scale_pos_weight=4.74 : y = 0.929 : 12.6 secs : infill_ei
#
# Thu Jul 31 18:31:22 2025 AUC 0.929908625254495
#
# [mbo] 375: num_leaves=17; min_data_in_leaf=36; learning_rate=0.0383; feature_fraction=0.881; bagging_fraction=0.963; max_depth=8; min_sum_hessian_in_leaf=0.0218; lambda_l1=2.3; lambda_l2=3.82; min_gain_to_split=0.0232; min_data_in_bin=9; max_bin=161; scale_pos_weight=4.55 : y = 0.93 : 12.2 secs : infill_ei
#
# Thu Jul 31 18:31:58 2025 AUC 0.930691673443396
#
# [mbo] 376: num_leaves=28; min_data_in_leaf=46; learning_rate=0.068; feature_fraction=0.967; bagging_fraction=0.934; max_depth=4; min_sum_hessian_in_leaf=0.0252; lambda_l1=2; lambda_l2=4.1; min_gain_to_split=0.0322; min_data_in_bin=4; max_bin=215; scale_pos_weight=0.712 : y = 0.931 : 13.1 secs : infill_ei
#
# Thu Jul 31 18:32:40 2025 AUC 0.930379319415507
#
# [mbo] 377: num_leaves=32; min_data_in_leaf=35; learning_rate=0.0249; feature_fraction=0.842; bagging_fraction=0.957; max_depth=7; min_sum_hessian_in_leaf=0.0614; lambda_l1=0.378; lambda_l2=4.15; min_gain_to_split=0.0285; min_data_in_bin=7; max_bin=103; scale_pos_weight=4.79 : y = 0.93 : 18.1 secs : infill_ei
#
# Saved the current state after iteration 378 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:33:21 2025 AUC 0.930009560828026
#
# [mbo] 378: num_leaves=19; min_data_in_leaf=41; learning_rate=0.0396; feature_fraction=0.843; bagging_fraction=0.948; max_depth=7; min_sum_hessian_in_leaf=0.0507; lambda_l1=2.82; lambda_l2=2.48; min_gain_to_split=0.0187; min_data_in_bin=4; max_bin=193; scale_pos_weight=4.51 : y = 0.93 : 11.5 secs : infill_ei
#
# Thu Jul 31 18:33:53 2025 AUC 0.929485226868423
#
# [mbo] 379: num_leaves=36; min_data_in_leaf=24; learning_rate=0.0695; feature_fraction=0.993; bagging_fraction=0.956; max_depth=5; min_sum_hessian_in_leaf=0.0406; lambda_l1=1.78; lambda_l2=3.91; min_gain_to_split=0.0878; min_data_in_bin=4; max_bin=158; scale_pos_weight=0.971 : y = 0.929 : 8.9 secs : infill_ei
#
# Thu Jul 31 18:34:29 2025 AUC 0.930229054921262
#
# [mbo] 380: num_leaves=42; min_data_in_leaf=17; learning_rate=0.0701; feature_fraction=0.86; bagging_fraction=0.933; max_depth=4; min_sum_hessian_in_leaf=0.0529; lambda_l1=2.25; lambda_l2=4.41; min_gain_to_split=0.0442; min_data_in_bin=6; max_bin=213; scale_pos_weight=0.566 : y = 0.93 : 13.0 secs : infill_ei
#
# Thu Jul 31 18:35:09 2025 AUC 0.929585500443631
#
# [mbo] 381: num_leaves=25; min_data_in_leaf=8; learning_rate=0.0268; feature_fraction=0.974; bagging_fraction=0.944; max_depth=7; min_sum_hessian_in_leaf=0.0402; lambda_l1=3.62; lambda_l2=4.75; min_gain_to_split=0.088; min_data_in_bin=6; max_bin=103; scale_pos_weight=4.85 : y = 0.93 : 17.0 secs : infill_ei
#
# Thu Jul 31 18:35:46 2025 AUC 0.930856812927362
#
# [mbo] 382: num_leaves=14; min_data_in_leaf=28; learning_rate=0.0365; feature_fraction=0.882; bagging_fraction=0.952; max_depth=8; min_sum_hessian_in_leaf=0.0115; lambda_l1=3.4; lambda_l2=4.11; min_gain_to_split=0.0984; min_data_in_bin=7; max_bin=140; scale_pos_weight=4.84 : y = 0.931 : 14.7 secs : infill_ei
#
# Thu Jul 31 18:36:24 2025 AUC 0.929579964439603
#
# [mbo] 383: num_leaves=16; min_data_in_leaf=34; learning_rate=0.031; feature_fraction=0.867; bagging_fraction=0.973; max_depth=8; min_sum_hessian_in_leaf=0.0781; lambda_l1=3.24; lambda_l2=4.21; min_gain_to_split=0.0491; min_data_in_bin=6; max_bin=139; scale_pos_weight=3.63 : y = 0.93 : 15.3 secs : infill_ei
#
# Thu Jul 31 18:37:08 2025 AUC 0.930264531703722
#
# [mbo] 384: num_leaves=40; min_data_in_leaf=8; learning_rate=0.0339; feature_fraction=0.866; bagging_fraction=0.935; max_depth=7; min_sum_hessian_in_leaf=0.0559; lambda_l1=3.51; lambda_l2=4.64; min_gain_to_split=0.0907; min_data_in_bin=7; max_bin=154; scale_pos_weight=4.77 : y = 0.93 : 21.2 secs : infill_ei
#
# Thu Jul 31 18:37:43 2025 AUC 0.928058287150541
#
# [mbo] 385: num_leaves=36; min_data_in_leaf=49; learning_rate=0.0338; feature_fraction=0.875; bagging_fraction=0.943; max_depth=8; min_sum_hessian_in_leaf=0.0166; lambda_l1=2.64; lambda_l2=4.37; min_gain_to_split=0.0135; min_data_in_bin=5; max_bin=152; scale_pos_weight=4.38 : y = 0.928 : 12.8 secs : infill_ei
#
# Thu Jul 31 18:38:20 2025 AUC 0.930744709966145
#
# [mbo] 386: num_leaves=15; min_data_in_leaf=23; learning_rate=0.034; feature_fraction=0.868; bagging_fraction=0.939; max_depth=8; min_sum_hessian_in_leaf=0.0458; lambda_l1=3.96; lambda_l2=1.73; min_gain_to_split=0.00583; min_data_in_bin=5; max_bin=144; scale_pos_weight=4.94 : y = 0.931 : 14.7 secs : infill_ei
#
# Thu Jul 31 18:38:56 2025 AUC 0.929960656248259
#
# [mbo] 387: num_leaves=20; min_data_in_leaf=11; learning_rate=0.0323; feature_fraction=0.811; bagging_fraction=0.975; max_depth=7; min_sum_hessian_in_leaf=0.0235; lambda_l1=2.13; lambda_l2=4.12; min_gain_to_split=0.0883; min_data_in_bin=4; max_bin=141; scale_pos_weight=4.84 : y = 0.93 : 12.6 secs : infill_ei
#
# Thu Jul 31 18:40:17 2025 AUC 0.930297949407255
#
# [mbo] 389: num_leaves=18; min_data_in_leaf=42; learning_rate=0.0219; feature_fraction=0.87; bagging_fraction=0.865; max_depth=8; min_sum_hessian_in_leaf=0.0503; lambda_l1=2.58; lambda_l2=4.31; min_gain_to_split=0.0215; min_data_in_bin=6; max_bin=239; scale_pos_weight=4.54 : y = 0.93 : 19.2 secs : infill_ei
#
# Thu Jul 31 18:40:57 2025 AUC 0.929403888873764
#
# [mbo] 390: num_leaves=13; min_data_in_leaf=28; learning_rate=0.034; feature_fraction=0.864; bagging_fraction=0.939; max_depth=8; min_sum_hessian_in_leaf=0.0221; lambda_l1=3.92; lambda_l2=3.28; min_gain_to_split=0.0142; min_data_in_bin=5; max_bin=172; scale_pos_weight=4.86 : y = 0.929 : 17.2 secs : infill_ei
#
# Thu Jul 31 18:41:33 2025 AUC 0.928766987886162
#
# [mbo] 391: num_leaves=22; min_data_in_leaf=39; learning_rate=0.0242; feature_fraction=0.821; bagging_fraction=0.941; max_depth=7; min_sum_hessian_in_leaf=0.0902; lambda_l1=2.42; lambda_l2=3.98; min_gain_to_split=0.022; min_data_in_bin=5; max_bin=226; scale_pos_weight=4.14 : y = 0.929 : 19.3 secs : infill_ei
#
# Thu Jul 31 18:42:08 2025 AUC 0.930255247336693
#
# [mbo] 392: num_leaves=23; min_data_in_leaf=13; learning_rate=0.0754; feature_fraction=0.954; bagging_fraction=0.943; max_depth=5; min_sum_hessian_in_leaf=0.00712; lambda_l1=1.66; lambda_l2=4.58; min_gain_to_split=0.0254; min_data_in_bin=6; max_bin=203; scale_pos_weight=0.612 : y = 0.93 : 12.2 secs : infill_ei
#
# Thu Jul 31 18:42:43 2025 AUC 0.929146781634323
#
# [mbo] 393: num_leaves=25; min_data_in_leaf=40; learning_rate=0.0365; feature_fraction=0.858; bagging_fraction=0.936; max_depth=8; min_sum_hessian_in_leaf=0.0722; lambda_l1=0.74; lambda_l2=4.21; min_gain_to_split=0.0318; min_data_in_bin=9; max_bin=125; scale_pos_weight=2.29 : y = 0.929 : 11.7 secs : infill_ei
#
# Thu Jul 31 18:43:26 2025 AUC 0.929942842706534
#
# [mbo] 394: num_leaves=19; min_data_in_leaf=33; learning_rate=0.0313; feature_fraction=0.888; bagging_fraction=0.945; max_depth=8; min_sum_hessian_in_leaf=0.0686; lambda_l1=3.4; lambda_l2=2.24; min_gain_to_split=0.00217; min_data_in_bin=7; max_bin=143; scale_pos_weight=3.01 : y = 0.93 : 17.3 secs : infill_ei
#
# Saved the current state after iteration 395 in the file bayesiana.RDATA.
#
# Thu Jul 31 18:44:12 2025 AUC 0.930480412002869
#
# [mbo] 395: num_leaves=15; min_data_in_leaf=41; learning_rate=0.0292; feature_fraction=0.859; bagging_fraction=0.93; max_depth=8; min_sum_hessian_in_leaf=0.0638; lambda_l1=2.03; lambda_l2=3.2; min_gain_to_split=0.0737; min_data_in_bin=3; max_bin=97; scale_pos_weight=4.94 : y = 0.93 : 13.2 secs : infill_ei
#
# Thu Jul 31 18:44:50 2025 AUC 0.929798310735332
#
# [mbo] 396: num_leaves=15; min_data_in_leaf=18; learning_rate=0.0312; feature_fraction=0.851; bagging_fraction=0.977; max_depth=7; min_sum_hessian_in_leaf=0.0385; lambda_l1=3.24; lambda_l2=0.834; min_gain_to_split=0.0836; min_data_in_bin=7; max_bin=140; scale_pos_weight=4.85 : y = 0.93 : 14.6 secs : infill_ei
#
# Thu Jul 31 18:45:29 2025 AUC 0.929128385226547
#
# [mbo] 397: num_leaves=13; min_data_in_leaf=7; learning_rate=0.037; feature_fraction=0.854; bagging_fraction=0.955; max_depth=7; min_sum_hessian_in_leaf=0.0514; lambda_l1=3.14; lambda_l2=4.83; min_gain_to_split=0.0325; min_data_in_bin=5; max_bin=148; scale_pos_weight=3.87 : y = 0.929 : 13.8 secs : infill_ei
#
# Thu Jul 31 18:46:09 2025 AUC 0.928998224630054
#
# [mbo] 398: num_leaves=23; min_data_in_leaf=25; learning_rate=0.0246; feature_fraction=0.941; bagging_fraction=0.94; max_depth=8; min_sum_hessian_in_leaf=0.0625; lambda_l1=3.14; lambda_l2=3.73; min_gain_to_split=0.0639; min_data_in_bin=4; max_bin=137; scale_pos_weight=2.46 : y = 0.929 : 17.8 secs : infill_ei
#
# Thu Jul 31 18:46:56 2025 AUC 0.929476385065119
#
# [mbo] 399: num_leaves=30; min_data_in_leaf=45; learning_rate=0.0282; feature_fraction=0.877; bagging_fraction=0.902; max_depth=8; min_sum_hessian_in_leaf=0.0772; lambda_l1=0.28; lambda_l2=4.29; min_gain_to_split=0.00363; min_data_in_bin=3; max_bin=240; scale_pos_weight=3.46 : y = 0.929 : 19.0 secs : infill_ei
#
# Thu Jul 31 18:47:35 2025 AUC 0.93077611663649
#
# [mbo] 400: num_leaves=16; min_data_in_leaf=41; learning_rate=0.025; feature_fraction=0.845; bagging_fraction=0.959; max_depth=7; min_sum_hessian_in_leaf=0.0128; lambda_l1=2.47; lambda_l2=4.27; min_gain_to_split=0.0126; min_data_in_bin=9; max_bin=133; scale_pos_weight=4.96 : y = 0.931 : 15.6 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_leaves"              "min_data_in_leaf"
#  [3] "learning_rate"           "feature_fraction"
#  [5] "bagging_fraction"        "max_depth"
#  [7] "min_sum_hessian_in_leaf" "lambda_l1"
#  [9] "lambda_l2"               "min_gain_to_split"
# [11] "min_data_in_bin"         "max_bin"
# [13] "scale_pos_weight"        "y"
# [15] "dob"                     "eol"
# [17] "error.message"           "exec.time"
# [19] "ei"                      "error.model"
# [21] "train.time"              "prop.type"
# [23] "propose.time"            "se"
# [25] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_leaves min_data_in_leaf learning_rate feature_fraction bagging_fraction
#         <int>            <int>         <num>            <num>            <num>
# 1:         25                6     0.0298533        0.8580961        0.9728787
#    max_depth min_sum_hessian_in_leaf lambda_l1 lambda_l2 min_gain_to_split
#        <int>                   <num>     <num>     <num>             <num>
# 1:         7              0.03660825  3.599401  4.379817        0.08330707
#    min_data_in_bin max_bin scale_pos_weight
#              <int>   <int>            <num>
# 1:               8     140         4.754341
# [1] 0.9315772

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] TRUE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100019
#
# $num_iterations
# [1] 400
#
# $early_stopping_round
# [1] 50
#
# $num_leaves
# [1] 25
#
# $min_data_in_leaf
# [1] 6
#
# $learning_rate
# [1] 0.0298533
#
# $feature_fraction
# [1] 0.8580961
#
# $bagging_fraction
# [1] 0.9728787
#
# $max_depth
# [1] 7
#
# $min_sum_hessian_in_leaf
# [1] 0.03660825
#
# $lambda_l1
# [1] 3.599401
#
# $lambda_l2
# [1] 4.379817
#
# $min_gain_to_split
# [1] 0.08330707
#
# $min_data_in_bin
# [1] 8
#
# $max_bin
# [1] 140
#
# $scale_pos_weight
# [1] 4.754341

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling

# %%
  # entreno LightGBM
dvalid <- dtrain
modelo_final <- lgb.train(
  data = dtrain,
  param = param_normalizado,
  valids = list(valid = dvalid)
)

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}
# Out:
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A
# Successfully submitted to Data Mining, Analista Sr 2025A

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Jul 31 19:26:50 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
